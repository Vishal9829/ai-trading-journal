# %%
# === CELL 1: SETUP ===

# !git clone https://github.com/Yui007/weebcentral_downloader.git
# %cd weebcentral_downloader

# Install requirements (if exists)
# !pip install -r requirements.txt || true

# Extra libs we’ll need later
# !pip install easyocr opencv-python-headless moviepy numpy
# Out:
# Cloning into 'weebcentral_downloader'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 213 (delta 25), reused 24 (delta 22), pack-reused 177 (from 1)
# Receiving objects: 100% (213/213), 625.87 KiB | 3.56 MiB/s, done.
# Resolving deltas: 100% (105/105), done.
# /content/weebcentral_downloader
